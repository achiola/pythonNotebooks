# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
n = 1000000
data = np.random.randn(n)

# %%
x = range(1,n+1)
plt.plot(x,data)

# %%
plt.hist(data)
# Out:
# (array([2.90000e+01, 1.04600e+03, 1.52840e+04, 1.00988e+05, 2.87716e+05,
#         3.55565e+05, 1.90453e+05, 4.44050e+04, 4.33500e+03, 1.79000e+02]),
#  array([-4.98615772, -4.03657854, -3.08699935, -2.13742017, -1.18784099,
#         -0.2382618 ,  0.71131738,  1.66089656,  2.61047574,  3.56005493,
#          4.50963411]),
#  <a list of 10 Patch objects>)

# %%
plt.plot(x,sorted(data))

# %% [markdown]
# ## Modificamos la media y la desviación estandard

# %%
mu = 5.5
sd = 2.5
data2 = mu + sd * np.random.randn(n)

# %%
plt.hist(data2)
# Out:
# (array([2.70000e+01, 1.14700e+03, 1.92810e+04, 1.32091e+05, 3.46562e+05,
#         3.47718e+05, 1.32981e+05, 1.91700e+04, 9.99000e+02, 2.40000e+01]),
#  array([-7.30705609, -4.74613073, -2.18520537,  0.37572   ,  2.93664536,
#          5.49757072,  8.05849608, 10.61942144, 13.18034681, 15.74127217,
#         18.30219753]),
#  <a list of 10 Patch objects>)

# %%
#generar un dataset aleatorio
np.random.randn(2,4)
# Out:
# array([[-1.00780154, -1.23073579, -0.99900983, -1.39492073],
#        [-1.54026947,  1.65546603,  0.32954884,  0.67878842]])
